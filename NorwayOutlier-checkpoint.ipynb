# %%
import pandas as pd
import seaborn as sb

# %%
data = pd.ExcelFile(r'C:\Users\sstirlin\Box\Machine Learning with Python\Final Project\WorldBank4.xlsx')

# %%
combined = pd.read_excel(data, 'Combined')

# %%
df = pd.DataFrame(data=combined)

# %%
sb.scatterplot(x='Children out of school, primary', y='GDP per capita (constant 2015 US$)', data=df, hue='Country',
                    sizes=(30, 200), legend='brief')

# %%
combined2 = pd.read_excel(data, 'Combined2')
df2 = pd.DataFrame(data=combined2)

# %%
sb.scatterplot(x='Children out of school, primary', y='GDP per capita (constant 2015 US$)', data=df2, hue='Country',
                    sizes=(30, 200), legend='brief')
