# %%
import pandas as pd
import plotly as pl
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import tree
from sklearn import preprocessing
from sklearn import utils

# %%
data = pd.ExcelFile(r'C:\Users\sstirlin\Box\Machine Learning with Python\Final Project\WorldBank.xlsx')

# %%
brazil = pd.read_excel(data, 'Brazil')
armenia = pd.read_excel(data, 'Armenia')
turkey = pd.read_excel(data, 'Turkey')
norway = pd.read_excel(data, 'Norway')
namibia = pd.read_excel(data, 'Namibia')

# %%
turkey.head()
# Out:
#    Year Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)  \
# 0  2000                                                 ..
# 1  2001                                                 ..
# 2  2002                                                2.1
# 3  2003                                                3.9
# 4  2004                                                  2
#
#   Access to electricity (% of population)  \
# 0                                      ..
# 1                                      ..
# 2                                      ..
# 3                                      ..
# 4                                      ..
#
#   Access to electricity, urban (% of urban population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Adjusted net national income (annual % growth)  \
# 0                                             ..
# 1                                             ..
# 2                                             ..
# 3                                             ..
# 4                                             ..
#
#    Adjusted net national income (current US$)  \
# 0                                2.269855e+11
# 1                                1.611733e+11
# 2                                1.924599e+11
# 3                                2.558359e+11
# 4                                3.365890e+11
#
#    Adjusted savings: gross savings (% of GNI)  \
# 0                                   21.720822
# 1                                   22.066970
# 2                                   22.886420
# 3                                   21.025099
# 4                                   22.617005
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                           11.80478
# 1                                            7.79516
# 2                                            6.64304
# 3                                            6.44075
# 4                                            5.79236
#
#    Age dependency ratio, young (% of working-age population)  \
# 0                                          48.343108
# 1                                          47.564413
# 2                                          46.691995
# 3                                          45.795415
# 4                                          44.953098
#
#   Cause of death, by non-communicable diseases (% of total)  \
# 0                                            80.1155
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#    Children out of school, primary  Current health expenditure (% of GDP)  \
# 0                           263011                               4.599572
# 1                           228366                               4.887849
# 2                           207841                               5.062279
# 3                           181104                               5.014277
# 4                           161550                               4.909644
#
#   External health expenditure per capita (current US$)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   External health expenditure per capita, PPP (current international $)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#    Foreign direct investment, net inflows (% of GDP)  \
# 0                                           0.357998
# 1                                           1.661453
# 2                                           0.450358
# 3                                           0.541017
# 4                                           0.681136
#
#    GDP per capita (constant 2015 US$)  GDP growth (annual %)
# 0                         6543.731447               6.933240
# 1                         6075.995627              -5.750007
# 2                         6373.131907               6.447722
# 3                         6644.145903               5.763206
# 4                         7194.682026               9.795936

# %%
df = pd.DataFrame(data=turkey)
turkey_subset = df.iloc[:, 7:10]
turkey_subset.head()
# Out:
#    Adjusted savings: gross savings (% of GNI)  \
# 0                                   21.720822
# 1                                   22.066970
# 2                                   22.886420
# 3                                   21.025099
# 4                                   22.617005
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                           11.80478
# 1                                            7.79516
# 2                                            6.64304
# 3                                            6.44075
# 4                                            5.79236
#
#    Age dependency ratio, young (% of working-age population)
# 0                                          48.343108
# 1                                          47.564413
# 2                                          46.691995
# 3                                          45.795415
# 4                                          44.953098

# %%
x = turkey_subset
y = turkey['Foreign direct investment, net inflows (% of GDP)']

# %%
x.head()
# Out:
#    Adjusted savings: gross savings (% of GNI)  \
# 0                                   21.720822
# 1                                   22.066970
# 2                                   22.886420
# 3                                   21.025099
# 4                                   22.617005
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                           11.80478
# 1                                            7.79516
# 2                                            6.64304
# 3                                            6.44075
# 4                                            5.79236
#
#    Age dependency ratio, young (% of working-age population)
# 0                                          48.343108
# 1                                          47.564413
# 2                                          46.691995
# 3                                          45.795415
# 4                                          44.953098

# %%
X_train, X_valid, y_train, y_valid = train_test_split(x, y, test_size = 0.2)
X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size = 0.25)

# %%
print('Train fraction: {}'.format((X_train.shape[0]) / x.shape[0]))
print('Validation fraction: {}'.format((X_valid.shape[0]  / x.shape[0])))
print('Test fraction: {}'.format((X_test.shape[0]  / x.shape[0])))
# Out:
# Train fraction: 0.8
# Validation fraction: 0.15
# Test fraction: 0.05

# %%
x.dtypes
# Out:
# Adjusted savings: gross savings (% of GNI)                     float64
# Adolescents out of school (% of lower secondary school age)    float64
# Age dependency ratio, young (% of working-age population)      float64
# dtype: object

# %%
lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y_train)

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(max_depth=5)

dt_model = dt_model.fit(X_train,y_train)
pred_dt = dt_model.predict_proba(X_test)[:, 1]
y_score = dt_model.fit(X_train, y_train).predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-108585db3b23> in <module>
#       3 dt_model = DecisionTreeClassifier(max_depth=5)
#       4
# ----> 5 dt_model = dt_model.fit(X_train,y_train)
#       6 pred_dt = dt_model.predict_proba(X_test)[:, 1]
#       7 y_score = dt_model.fit(X_train, y_train).predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     179
#     180         if is_classification:
# --> 181             check_classification_targets(y)
#     182             y = np.copy(y)
#     183
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'
